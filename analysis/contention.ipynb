# %%
from utils import *
import matplotlib.pyplot as plt

# %%
data = get_mixrw_rate('../results/Contention-30', step=10)
# Out:
# files:
# ../results/Contention-30/MIXREADWRITE-0.0.dat
# ../results/Contention-30/MIXREADWRITE-0.1.dat
# ../results/Contention-30/MIXREADWRITE-0.2.dat
# ../results/Contention-30/MIXREADWRITE-0.3.dat
# ../results/Contention-30/MIXREADWRITE-0.4.dat
# ../results/Contention-30/MIXREADWRITE-0.5.dat
# ../results/Contention-30/MIXREADWRITE-0.6.dat
# ../results/Contention-30/MIXREADWRITE-0.7.dat
# ../results/Contention-30/MIXREADWRITE-0.8.dat
# ../results/Contention-30/MIXREADWRITE-0.9.dat
# ../results/Contention-30/MIXREADWRITE-1.0.dat

# %%
avg = {}
for i, d in data.items():
    avg[i] = avg_rate(d, filter=0)

# %%
x = []
y = []
for k, v in avg.items():
    x.append(k)
    y.append(v)

plt.figure()
plt.plot(x, y)
plt.xlabel('Read Percentage')
plt.ylabel('Write Percentage')
plt.title('Contention Throughput')
plt.show()
